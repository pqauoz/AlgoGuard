# %% [markdown]
# # Local Detection
#
# This archived notebook is reserved for the local-traffic detection experiment. The operational Flask workflow is implemented in the root application and `services/` package.
